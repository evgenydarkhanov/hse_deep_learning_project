# %% [markdown]
# **гибридный поиск версия 1.1:**
#
# в гибридном поиске добавлен выбор между:
# - взвешенная сумма + топ-N
# - взвешенная сумма + Max pooling + топ-N

# %% [markdown]
# **dataframes concatenation**

# %%
# %%capture
# !pip install openpyxl

# %%
import pandas as pd

# %%
df_req_cer = pd.read_excel('ВК_Реквизиты_Справки.xlsx')
df_doc_pen = pd.read_excel('ВК_Документ_Пенсия.xlsx')

assert len(df_req_cer.columns.tolist()) == len(df_doc_pen.columns.tolist()), "different num of columns"
assert df_req_cer.columns.tolist() == df_doc_pen.columns.tolist(), "different columns"

df = pd.concat([df_doc_pen, df_req_cer], ignore_index=True)
df
# Out:
#                     Краткое наименование услуги (суть)  \
# 0                               Удостоверение инвалида
# 1                      Дубликат удостоверения инвалида
# 2     Дубликат пенсионного удостоверения от Военкомата
# 3                Удостоверение ветерана военной службы
# 4       Дубликат удостоверения ветерана военной службы
# ..                                                 ...
# 140  Выдача справок о праве на получение компенсаци...
# 141  Справка о праве на получение компенсаций расхо...
# 142  Справка о праве на получение компенсационных в...
# 143  Выдача справок о праве на получение компенсаци...
# 144  Выдача справок о праве на получение компенсаци...
#
#     Кодирование в АИС МФЦ / СЭО  \
# 0                    ДОКУМЕНТ01
# 1                    ДОКУМЕНТ01
# 2                    ДОКУМЕНТ02
# 3                    ДОКУМЕНТ03
# 4                    ДОКУМЕНТ03
# ..                          ...
# 140                   СПРАВКА10
# 141                   СПРАВКА10
# 142                   СПРАВКА10
# 143                   СПРАВКА10
# 144                   СПРАВКА10
#
#                                        Заявитель в МФЦ  \
# 0    Гражданин РФ, являющийся инвалидом вследствии ...
# 1    Гражданин РФ, являющийся инвалидом вследствии ...
# 2    Гражданин РФ, состоящий на пенсионном обеспече...
# 3    1. Гражданин РФ, состоящий на пенсионном обесп...
# 4    1. Гражданин РФ, состоящий на пенсионном обесп...
# ..                                                 ...
# 140  1. Члены семей военнослужащих, погибших (умерш...
# 141  1. Члены семей военнослужащих, погибших (умерш...
# 142  1. Члены семей военнослужащих, погибших (умерш...
# 143  1. Члены семей военнослужащих, погибших (умерш...
# 144  1. Члены семей военнослужащих, погибших (умерш...
#
#            Способ подачи документов  \
# 0    1. Лично в МФЦ\n2. Лично в ОИВ
# 1    1. Лично в МФЦ\n2. Лично в ОИВ
# 2    1. Лично в МФЦ\n2. Лично в ОИВ
# 3    1. Лично в МФЦ\n2. Лично в ОИВ
# 4    1. Лично в МФЦ\n2. Лично в ОИВ
# ..                              ...
# 140                     Лично в МФЦ
# 141                     Лично в МФЦ
# 142                     Лично в МФЦ
# 143                     Лично в МФЦ
# 144                     Лично в МФЦ
#
#                        Способ выдачи результата услуги  \
# 0    1. Лично в МФЦ\n2. Лично в ОИВ (в случае подач...
# 1    1. Лично в МФЦ\n2. Лично в ОИВ (в случае подач...
# 2    1. Лично в МФЦ\n2. Лично в ОИВ (в случае подач...
# 3    1. Лично в МФЦ\n2. Лично в ОИВ (в случае подач...
# 4    1. Лично в МФЦ\n2. Лично в ОИВ (в случае подач...
# ..                                                 ...
# 140                                        Лично в МФЦ
# 141                                        Лично в МФЦ
# 142                                        Лично в МФЦ
# 143                                        Лично в МФЦ
# 144                                        Лично в МФЦ
#
#     Пакет документов для отправки в Военкомат при личном обращении:  \
# 0    1. Заявление. \n2. Паспорт гражданина РФ (копи...
# 1    1. Заявление. \n2. Паспорт гражданина РФ (копи...
# 2    1. Заявление. \n2. Паспорт РФ (копия). \n3. Фо...
# 3    1. Заявление (первичное). \n2. Паспорт граждан...
# 4    1. Заявление (дубликат). \n2. Паспорт граждани...
# ..                                                 ...
# 140  1. Заявление. 2. Паспорт РФ (копия). 3. Свидет...
# 141  1. Заявление. 2. Паспорт РФ (копия). 3. Свидет...
# 142  1. Заявление. 2. Паспорт РФ (копия). 3. Свидет...
# 143  1. Заявление. 2. Паспорт РФ (копия). 3. Свидет...
# 144  1. Заявление. 2. Паспорт РФ (копия). 3. Свидет...
#
#     Пакет документов для отправки в Военкомат при обращении доверенного лица дополнительно предоставляют:  \
# 0    1. Паспорт доверенного лица (копия). \n2. Копи...
# 1    1. Паспорт доверенного лица (копия). \n2. Копи...
# 2    1. Паспорт доверенного лица (копия). \n2. Копи...
# 3    1. Паспорт доверенного лица (копия). \n2. Копи...
# 4    1. Паспорт доверенного лица (копия). \n2. Копи...
# ..                                                 ...
# 140  1. Паспорт доверенного лица (копия). 2. Копия ...
# 141  1. Паспорт доверенного лица (копия). 2. Копия ...
# 142  1. Паспорт доверенного лица (копия). 2. Копия ...
# 143  1. Паспорт доверенного лица (копия). 2. Копия ...
# 144  1. Паспорт доверенного лица (копия). 2. Копия ...
#
#                             Срок предоставления услуги  \
# 0                                  30 календарных дней
# 1                                  30 календарных дней
# 2                                  30 календарных дней
# 3    21 день для направления документов в Миноборон...
# 4    21 день для направления документов в Миноборон...
# ..                                                 ...
# 140                                30 календарных дней
# 141                                30 календарных дней
# 142                                30 календарных дней
# 143                                30 календарных дней
# 144                                30 календарных дней
#
#                        Результат предоставления услуги  \
# 0    1. Удостоверение «Инвалида о праве на льготы»....
# 1    1. Дубликат удостоверения «Инвалида о праве на...
# 2    1. Дубликат пенсионного удостоверения. \n2. Ув...
# 3    1. Удостоверение «Ветеран военной службы». \n2...
# 4    1. Дубликат удостоверения «Ветеран военной слу...
# ..                                                 ...
# 140  1. Справка. 2. Уведомление об отказе в выдаче ...
# 141  1. Справка. 2. Уведомление об отказе в выдаче ...
# 142  1. Справка. 2. Уведомление об отказе в выдаче ...
# 143  1. Справка. 2. Уведомление об отказе в выдаче ...
# 144  1. Справка. 2. Уведомление об отказе в выдаче ...
#
#     Возможность совместной подачи
# 0             ВЫПЛАТЫ05\nПЕНСИЯ03
# 1             ВЫПЛАТЫ05\nПЕНСИЯ03
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 140                           NaN
# 141                           NaN
# 142                           NaN
# 143                           NaN
# 144                           NaN
#
# [145 rows x 10 columns]

# %% [markdown]
# **вытаскиваем колонку, которая будет векторизоваться и по которой будет производиться поиск**

# %%
services = df['Краткое наименование услуги (суть)']
services_list = services.tolist()
services
# Out:
# 0                                 Удостоверение инвалида
# 1                        Дубликат удостоверения инвалида
# 2       Дубликат пенсионного удостоверения от Военкомата
# 3                  Удостоверение ветерана военной службы
# 4         Дубликат удостоверения ветерана военной службы
#                              ...
# 140    Выдача справок о праве на получение компенсаци...
# 141    Справка о праве на получение компенсаций расхо...
# 142    Справка о праве на получение компенсационных в...
# 143    Выдача справок о праве на получение компенсаци...
# 144    Выдача справок о праве на получение компенсаци...
# Name: Краткое наименование услуги (суть), Length: 145, dtype: object

# %% [markdown]
# ### **`BM25`-part**
#
# - [BM25](https://github.com/dorianbrown/rank_bm25)
# - Note that this package doesn't do any text preprocessing. If you want to do things like lowercasing, stopword removal, stemming, etc, you need to do it yourself.
# - The only requirements is that the class receives a list of lists of strings, which are the document tokens.
# - Good to note that we also need to tokenize our query, and apply the same preprocessing steps we did to the documents in order to have an apples-to-apples comparison

# %%
# %%capture
# !pip install rank_bm25
# !pip install pymystem3
# !pip install pymorphy2==0.8

# %%
import numpy as np
from rank_bm25 import BM25Okapi

# %%
import re
import pymorphy2

# стоп-слова грузим отдельно
with open('/home/darhanovev/stopwords/russian.txt', 'r') as file:
    stop_words = {word.strip() for word in file}

lemmatizer = pymorphy2.MorphAnalyzer()

# %%
TOKEN_WORD = re.compile('[а-яА-ЯёЁ]{2,}')


def remove_lemmatize_preprocessing(sentence: str, words_to_remove: set) -> list:
    """ приводит к нижнему регистру, убирает числа и мусорные слова, лемматизирует """
    if isinstance(sentence, str):
        regex_tmp = re.findall(TOKEN_WORD, sentence.lower())
        remove_tmp = [lemmatizer.parse(token.strip())[0].normal_form for token in regex_tmp if token not in words_to_remove]
        return remove_tmp
    return []


def one_sentence_preprocessing(sentence: str, words_to_remove: set) -> str:
    """ применяет препроцессинги к одному предложению """
    sentence_words = remove_lemmatize_preprocessing(sentence, words_to_remove)
    result = ' '.join(sentence_words)
    return result

# %%
services_tokenized = [one_sentence_preprocessing(service, stop_words).split() for service in services_list]
services_tokenized[:10]
# Out:
# [['удостоверение', 'инвалид'],
#  ['дубликат', 'удостоверение', 'инвалид'],
#  ['дубликат', 'пенсионный', 'удостоверение', 'военкомат'],
#  ['удостоверение', 'ветеран', 'военный', 'служба'],
#  ['дубликат', 'удостоверение', 'ветеран', 'военный', 'служба'],
#  ['удостоверение', 'ветеран', 'боев', 'действие'],
#  ['дубликат', 'удостоверение', 'ветеран', 'боев', 'действие'],
#  ['удостоверение', 'член', 'семья', 'умерший', 'ветеран', 'боев', 'действие'],
#  ['дубликат',
#   'удостоверение',
#   'член',
#   'семья',
#   'умерший',
#   'ветеран',
#   'боев',
#   'действие'],
#  ['продление', 'выплата', 'пенсия', 'случай', 'потеря', 'кормилец']]

# %%
bm25_vk = BM25Okapi(services_tokenized)


def make_query_bm_25(query: str,
                     top: int = 5,
                     corpus=services,
                     words_to_remove: set = stop_words):
    """
    возвращает:
        - [{'corpus_id': id, 'score': score}, ...]
        - score - значения Okapi BM25 в диапазоне [0, 1]
    """

    query_cleaned = one_sentence_preprocessing(query, words_to_remove)
    query_tokenized = query_cleaned.split()

    scores = bm25_vk.get_scores(query_tokenized)
    scores /= np.max(scores)

    top_k = np.argsort(scores)[::-1][:top]
    result = [{'corpus_id': i, 'score': scores[i]} for i in top_k]
    # result = [corpus[i] for i in top_k]

    return result

# %%
scores = make_query_bm_25('Дубликат пенсионного удостоверения от Военкомата')
scores
# Out:
# [{'corpus_id': 2, 'score': 1.0},
#  {'corpus_id': 1, 'score': 0.43206680797888897},
#  {'corpus_id': 4, 'score': 0.35977870741319035},
#  {'corpus_id': 6, 'score': 0.35977870741319035},
#  {'corpus_id': 8, 'score': 0.28760173382760795}]

# %% [markdown]
# ### **cosine similarity part**
#
# - `Sentence Transformers`
# - эмбеддер: `ruBERT-tiny2`
# - [Hugging Face](https://huggingface.co/cointegrated/rubert-tiny2)

# %%
# %%capture
# !pip install torch
# !pip install transformers
# !pip install sentence_transformers

# %%
import torch
from sentence_transformers import SentenceTransformer, util

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
rubert_tiny_path = "/home/darhanovev/hugging_face/rubert_tiny2"

model_cosine = SentenceTransformer(
    model_name_or_path=rubert_tiny_path,
    device=device,
    local_files_only=True
)

# %%
services_emb_cos = model_cosine.encode(services_list)


def make_query_cosine(query: str,
                      top: int = 5,
                      model=model_cosine,
                      embeddings=services_emb_cos):
    """
    возвращает:
        - [{'corpus_id': id, 'score': score}, ...]
        - score - нормированная на диапазон [0, 1] косинусная близость
    """

    query_emb = model.encode(query)
    result = util.semantic_search(query_emb, embeddings)[0][:top]
    for dct in result:
        dct['score'] = (dct['score'] + 1) / 2

    return result

# %%
result = make_query_cosine('Дубликат пенсионного удостоверения от Военкомата')
result
# Out:
# [{'corpus_id': 2, 'score': 1.0000000596046448},
#  {'corpus_id': 1, 'score': 0.9290907979011536},
#  {'corpus_id': 4, 'score': 0.9099321365356445},
#  {'corpus_id': 11, 'score': 0.9039898216724396},
#  {'corpus_id': 60, 'score': 0.9038759768009186}]

# %%
for dct in result:
    print(dct['score'], services_list[dct['corpus_id']])
# Out:
# 1.0000000596046448 Дубликат пенсионного удостоверения от Военкомата
# 0.9290907979011536 Дубликат удостоверения инвалида
# 0.9099321365356445 Дубликат удостоверения ветерана военной службы
# 0.9039898216724396 Назначение пенсии по инвалидности
# 0.9038759768009186 Справка о получении пенсии военному

# %% [markdown]
# ### **`Bi-Encoder`-part**
#
# - асимметричный поиск
# - эмбеддер: `ruBERT`
# - [Hugging Face](https://huggingface.co/DiTy/bi-encoder-russian-msmarco)
# - [статья с Хабра](https://habr.com/ru/articles/834356/)

# %%
# %%capture
# !pip install torch
# !pip install sentence_transformers
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
import torch
from sentence_transformers import SentenceTransformer, util

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
bi_encoder_path = "/home/darhanovev/hugging_face/bi_encoder_russian_msmarco"

model_bi = SentenceTransformer(
    model_name_or_path=bi_encoder_path,
    device=device,
    local_files_only=True
)

# %%
services_emb_bi = model_bi.encode(services_list)


def make_query_asymm(query: str,
                     top: int = 5,
                     model=model_bi,
                     embeddings=services_emb_bi):
    """
    возвращает:
        - [{'corpus_id': id, 'score': score}, ...]
        - score - нормированная на диапазон [0, 1] косинусная близость
    """

    query_emb = model.encode(query)
    result = util.semantic_search(query_emb, embeddings)[0][:top]
    for dct in result:
        dct['score'] = (dct['score'] + 1) / 2

    return result

# %%
result = make_query_asymm('Дубликат пенсионного удостоверения от Военкомата')
result
# Out:
# [{'corpus_id': 2, 'score': 1.0},
#  {'corpus_id': 4, 'score': 0.7623136341571808},
#  {'corpus_id': 1, 'score': 0.7546685338020325},
#  {'corpus_id': 6, 'score': 0.7182275950908661},
#  {'corpus_id': 8, 'score': 0.6954275071620941}]

# %%
for dct in result:
    print(dct['score'], services_list[dct['corpus_id']])
# Out:
# 1.0 Дубликат пенсионного удостоверения от Военкомата
# 0.7623136341571808 Дубликат удостоверения ветерана военной службы
# 0.7546685338020325 Дубликат удостоверения инвалида
# 0.7182275950908661 Дубликат удостоверения ветерана боевых действий
# 0.6954275071620941 Дубликат удостоверения члену семьи умершего ветерана боевых действий

# %% [markdown]
# ### **unite them**

# %%
def scores_merging_sum(scores_one, scores_two):
    """
    объединяет результаты двух поисковиков
    оставляет уникальные ключи, суммирует скоры
    возвращает {id: score}
    """
    for key, value in scores_two.items():
        if key not in scores_one:
            scores_one[key] = value
        else:
            scores_one[key] += value

    return scores_one


def scores_merging_max(scores_one, scores_two):
    """
    объединяет результаты двух поисковиков
    оставляет уникальные ключи, берёт наибольшие скоры
    возвращает {id: score}
    """
    for key, value in scores_two.items():
        if key not in scores_one:
            scores_one[key] = value
        if scores_one[key] < value:
            scores_one[key] = value

    return scores_one


def scores_merging_unique_id(scores_one, scores_two, df):
    """
    объединяет результаты двух поисковиков
    оставляет уникальные ключи, уникальные id типа 'ДОКУМЕНТ01'
    берёт наибольшие скоры
    возвращает {unique_id: (id, score)}
    """
    result = {}
    for key, value in scores_one.items():
        new_key = df.iloc[key, 1]
        if new_key not in result:
            result[new_key] = (key, value)
        if result[new_key][1] < value:
            result[new_key] = (key, value)

    for key, value in scores_two.items():
        new_key = df.iloc[key, 1]
        if new_key not in result:
            result[new_key] = (key, value)
        if result[new_key][1] < value:
            result[new_key] = (key, value)

    return result

# %%
def hybrid_search(
    query: str,
    top: int = 5,
    weights={'bm_25': 0.333, 'cosine': 0.333, 'asymm': 0.333},
    dataframe=df,
    mode=['sum', 'max', 'unique'],
    retrieve_bm_25=make_query_bm_25,
    retrieve_cosine=make_query_cosine,
    retrieve_asymm=make_query_asymm
):
    """
    возвращает спискок кортежей вида [(corpus_id: int, score: float), ...]
                            или вида [(unique_id: str, (corpus_id: int, score: float)), ...]
    """
    scores_bm_25 = { dct['corpus_id']: dct['score'] * weights['bm_25'] for dct in make_query_bm_25(query, top) }
    scores_cosine = { dct['corpus_id']: dct['score'] * weights['cosine'] for dct in make_query_cosine(query, top) }
    scores_asymm = { dct['corpus_id']: dct['score'] * weights['asymm'] for dct in make_query_asymm(query, top) }

    if mode == 'sum':
        scores_tmp = scores_merging_sum(scores_bm_25, scores_cosine)
        scores = scores_merging(scores_tmp, scores_asymm)
        scores = sorted(scores.items(), key=lambda item: item[1], reverse=True)[:top]
    if mode == 'max':
        scores_tmp = scores_merging_max(scores_bm_25, scores_cosine)
        scores = scores_merging(scores_tmp, scores_asymm)
        scores = sorted(scores.items(), key=lambda item: item[1], reverse=True)[:top]
    if mode == 'unique_id':
        scores_tmp = scores_merging_unique_id(scores_bm_25, scores_cosine)
        scores = scores_merging_unique_id(scores_tmp, scores_asymm)
        scores = sorted(scores.items(), key=lambda item: item[1][1], reverse=True)[:top]

    return scores

# %%
def make_query_hybrid(
    query: str,
    top_to_show: int = 5,
    corpus=df,
    mode=['sum', 'max', 'unique']
):
    result = hybrid_search(query)
    if mode == 'sum' or mode == 'max':
        for idx in range(top_to_show):
            print(f"QUERY: {query}")
            df_idx = result[idx][0]
            print(df.iloc[df_idx].tolist())
            print("\n==========================\n")

    if mode == 'uniqie':
        for idx in range(top_to_show):
            print(f"QUERY: {query}")
            df_idx = result[idx][1][0]
            print(df.iloc[df_idx].tolist())
            print("\n==========================\n")

# %%
make_query_hybrid('Дубликат пенсионного удостоверения от Военкомата')
